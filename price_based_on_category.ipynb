# %%
import pandas as pd
import numpy as np

# Get a random sample from the training set
# data = pd.read_table('/Users/David/Desktop/Mercari/train.tsv')
# data_nrows = data.shape[0]
# data['random'] = pd.Series(np.random.randn(data_nrows), index=data.index)
# sorted_data = data.sort_values(by=['random'])
# random_sample = sorted_data.head(148254)
# random_sample.to_csv("/Users/David/Desktop/Mercari/random_sample.tsv", sep='\t', index=False)

# Load random sample after it's been written for the first time
random_sample = pd.read_table('/Users/David/Desktop/Mercari/random_sample.tsv')

# Load category metadata and get expected price per item based on category
categories = pd.read_table('/Users/David/Desktop/Mercari/statsBySubcategory.csv', sep=",")

# Predict price based on category
predictions = random_sample.set_index('category_name').join(categories.set_index('Category'), how='left')
deviations = abs(predictions['price'] - predictions['Median']) / predictions['price']

# Return an estimate of accuracy of predictions
import math
accuracy = 1 - np.median(list(filter(lambda deviation: not math.isnan(deviation), deviations)))

# %%
accuracy
# Out:
# 0.59999999999999998

# %%
import re

# Clean up descriptions
alpha_descriptions = list(map(lambda description: re.sub(r"[^a-zA-Z ]", '', description.lower()), random_sample['item_description']))

# Unique words
split_descriptions = map(lambda alpha: alpha.split(), iter(alpha_descriptions))
all_keywords = [keyword for description in split_descriptions for keyword in description]
unique_keywords = set(all_keywords)

# Number of items with each word (smaller sample)
keyword_counts = list(map(lambda keyword: (keyword, len([alpha for alpha in iter(alpha_descriptions) if keyword in alpha])), list(unique_keywords)[0:1000]))
keyword_counts
# Out:
# [('bodywash', 15),
#  ('fisherman', 8),
#  ('eyestays', 1),
#  ('taxfreeshopping', 1),
#  ('brae', 2),
#  ('monitormake', 1),
#  ('refurbishing', 1),
#  ('facedpinkurban', 1),
#  ('frankensteins', 3),
#  ('gong', 4),
#  ('cancelations', 4),
#  ('looooove', 2),
#  ('yetplease', 1),
#  ('thunderstruck', 1),
#  ('ffa', 232),
#  ('reglue', 5),
#  ('mouthwashes', 1),
#  ('twin', 226),
#  ('rufflebutt', 2),
#  ('bolder', 4),
#  ('primeexpress', 1),
#  ('scrunchie', 10),
#  ('obstruct', 8),
#  ('brushnose', 3),
#  ('thxx', 1),
#  ('complained', 2),
#  ('messes', 2),
#  ('miro', 6),
#  ('cobra', 9),
#  ('thirstquencher', 1),
#  ('tns', 2),
#  ('rats', 24),
#  ('cubescrumbles', 2),
#  ('mahou', 2),
#  ('jfc', 7),
#  ('ooze', 11),
#  ('purchasebeautiful', 1),
#  ('harveys', 3),
#  ('spacedye', 1),
#  ('police', 23),
#  ('cattle', 2),
#  ('hind', 120),
#  ('plateplatter', 1),
#  ('hicolor', 1),
#  ('cavali', 13),
#  ('garentee', 1),
#  ('warmthick', 1),
#  ('suitcaseperfect', 1),
#  ('fuzzhead', 1),
#  ('notebook', 95),
#  ('softens', 28),
#  ('centrum', 1),
#  ('afraid', 37),
#  ('aspire', 12),
#  ('overlays', 13),
#  ('rmpair', 5),
#  ('gearcar', 8),
#  ('ivypark', 1),
#  ('favors', 26),
#  ('colorlusty', 1),
#  ('cameraready', 1),
#  ('newtc', 1),
#  ('collareasy', 1),
#  ('planets', 4),
#  ('holographicaliencalifornia', 5),
#  ('grandchildren', 1),
#  ('immune', 15),
#  ('anthem', 18),
#  ('thesr', 2),
#  ('benzoyl', 5),
#  ('furlike', 1),
#  ('cocoabeach', 1),
#  ('hyde', 8),
#  ('morphing', 1),
#  ('reflex', 13),
#  ('judy', 6),
#  ('resharpened', 3),
#  ('welcomebundle', 1),
#  ('lowpower', 2),
#  ('matt', 1664),
#  ('adonna', 9),
#  ('crosspad', 1),
#  ('alchemy', 2),
#  ('mdium', 6),
#  ('assembled', 45),
#  ('vac', 356),
#  ('cosmeceuticals', 4),
#  ('kinds', 76),
#  ('nice', 1831),
#  ('onlyfashionable', 1),
#  ('tanblack', 2),
#  ('charing', 4),
#  ('riseperfect', 1),
#  ('resides', 1),
#  ('mild', 112),
#  ('plusfjuniors', 1),
#  ('ferrero', 1),
#  ('oneor', 2),
#  ('sculpture', 15),
#  ('recamended', 1),
#  ('arkansas', 3),
#  ('marquise', 5),
#  ('italy', 120),
#  ('comfortableflexible', 1),
#  ('cougars', 2),
#  ('delayvacationillnessweather', 2),
#  ('toadettes', 1),
#  ('presto', 15),
#  ('dia', 2324),
#  ('burp', 21),
#  ('nutrients', 24),
#  ('belts', 54),
#  ('deadshot', 1),
#  ('freshfruit', 1),
#  ('examined', 6),
#  ('muzzle', 1),
#  ('onetime', 1),
#  ('prescriptions', 2),
#  ('trickortreating', 2),
#  ('marquee', 3),
#  ('facetime', 18),
#  ('purpleyellowgreen', 1),
#  ('severus', 3),
#  ('ys', 10761),
#  ('crossbodyvanilla', 1),
#  ('underrated', 1),
#  ('lipglosslipstick', 2),
#  ('spacey', 2),
#  ('ozoz', 54),
#  ('huntnew', 1),
#  ('kettles', 2),
#  ('starches', 4),
#  ('translates', 4),
#  ('chuggington', 1),
#  ('touch', 1068),
#  ('raye', 181),
#  ('kari', 23),
#  ('grapefruit', 64),
#  ('headbandear', 1),
#  ('helium', 4),
#  ('dsfull', 1),
#  ('entouragebridesmaids', 1),
#  ('desirable', 3),
#  ('resemble', 13),
#  ('songbird', 1),
#  ('handbook', 5),
#  ('runner', 48),
#  ('doux', 1),
#  ('cashin', 1),
#  ('greyishpurple', 2),
#  ('mitts', 3),
#  ('cmxcm', 1),
#  ('higley', 1),
#  ('postcoloring', 1),
#  ('kreme', 1),
#  ('unhappy', 14),
#  ('bbd', 3),
#  ('slowly', 49),
#  ('alabaster', 5),
#  ('squeezes', 3),
#  ('pertaining', 2),
#  ('trding', 2),
#  ('accessorieswomeneye', 3),
#  ('hisher', 3),
#  ('undaunted', 1),
#  ('jenner', 243),
#  ('martians', 1),
#  ('covershot', 1),
#  ('powderbaking', 1),
#  ('falalaspoon', 1),
#  ('supershine', 1),
#  ('kens', 113),
#  ('traditions', 7),
#  ('dentists', 3),
#  ('sarahpetrik', 1),
#  ('taotronics', 1),
#  ('stickydirty', 1),
#  ('sweatersweatshirt', 1),
#  ('necklinedeep', 1),
#  ('inventorywith', 1),
#  ('julezfoolz', 1),
#  ('braces', 10),
#  ('steamies', 1),
#  ('scratchingflaking', 1),
#  ('siphon', 18),
#  ('notocible', 1),
#  ('operations', 3),
#  ('byham', 1),
#  ('slicessize', 1),
#  ('tempera', 207),
#  ('alexis', 9),
#  ('trashy', 1),
#  ('japonesque', 3),
#  ('repairwear', 6),
#  ('paslock', 1),
#  ('fireman', 3),
#  ('jamssize', 1),
#  ('halloweens', 1),
#  ('soames', 1),
#  ('greylight', 3),
#  ('khost', 1),
#  ('starr', 40),
#  ('objectcreate', 1),
#  ('lovej', 1),
#  ('andersdon', 1),
#  ('relative', 20),
#  ('usedlet', 1),
#  ('plague', 1),
#  ('attaches', 39),
#  ('benwolf', 1),
#  ('gelato', 6),
#  ('fullqueen', 13),
#  ('pilot', 33),
#  ('kathleens', 1),
#  ('breaded', 1),
#  ('kae', 6),
#  ('jeepnation', 2),
#  ('turnip', 2),
#  ('rivers', 32),
#  ('intervals', 3),
#  ('rubber', 574),
#  ('missions', 4),
#  ('eyeopening', 1),
#  ('unicorns', 117),
#  ('serving', 59),
#  ('theia', 1),
#  ('jewlery', 6),
#  ('flickers', 1),
#  ('vv', 79),
#  ('soundly', 1),
#  ('aria', 186),
#  ('smallxxxl', 1),
#  ('twingaroo', 1),
#  ('punisher', 15),
#  ('pass', 349),
#  ('thrilled', 1),
#  ('aromatherapist', 1),
#  ('saturday', 264),
#  ('threeor', 1),
#  ('statements', 3),
#  ('clark', 28),
#  ('knocking', 2),
#  ('adjustablethese', 1),
#  ('zeep', 2),
#  ('icecream', 2),
#  ('biting', 6),
#  ('singleserve', 1),
#  ('volumize', 12),
#  ('starfleet', 1),
#  ('jeansloose', 1),
#  ('andpink', 1),
#  ('forza', 4),
#  ('vvhtf', 4),
#  ('tartlettes', 1),
#  ('achieves', 1),
#  ('karmala', 1),
#  ('combinationoily', 3),
#  ('baguettes', 1),
#  ('pumps', 91),
#  ('bazilian', 1),
#  ('dukesigned', 1),
#  ('courteous', 21),
#  ('xw', 37),
#  ('asepsis', 1),
#  ('thorough', 75),
#  ('potent', 46),
#  ('smee', 4),
#  ('sketchers', 33),
#  ('samsonite', 2),
#  ('mukluk', 3),
#  ('dracula', 7),
#  ('shirty', 1),
#  ('spikes', 19),
#  ('ii', 913),
#  ('outcomes', 2),
#  ('survived', 2),
#  ('blanketsare', 1),
#  ('jacana', 1),
#  ('degraded', 1),
#  ('african', 66),
#  ('livas', 2),
#  ('labels', 209),
#  ('sportinfluenced', 1),
#  ('graveyards', 1),
#  ('colorcherokee', 1),
#  ('mornings', 16),
#  ('tixs', 2),
#  ('naturallybased', 2),
#  ('pictureddust', 1),
#  ('fithow', 1),
#  ('accessoriesmanuals', 1),
#  ('julliangagnier', 1),
#  ('prong', 43),
#  ('haute', 9),
#  ('breastpump', 6),
#  ('informative', 1),
#  ('compatibleall', 1),
#  ('thexandsuper', 1),
#  ('backdrop', 5),
#  ('litchee', 1),
#  ('rumpled', 2),
#  ('vintageantique', 1),
#  ('alyssum', 1),
#  ('muted', 22),
#  ('textured', 122),
#  ('poron', 2),
#  ('dead', 284),
#  ('rises', 29),
#  ('usedonly', 1),
#  ('assassin', 20),
#  ('pinksize', 2),
#  ('minks', 2),
#  ('merr', 67),
#  ('voices', 8),
#  ('ryker', 1),
#  ('imperfection', 425),
#  ('ereaders', 1),
#  ('nad', 114),
#  ('terranova', 1),
#  ('nillionare', 2),
#  ('blacknavy', 1),
#  ('randomthank', 4),
#  ('mancini', 1),
#  ('singing', 8),
#  ('backpackmulti', 1),
#  ('posti', 140),
#  ('justbaked', 1),
#  ('detail', 2312),
#  ('antiredness', 1),
#  ('smallaccessories', 1),
#  ('gvp', 1),
#  ('exfolikate', 5),
#  ('skrit', 1),
#  ('inclusive', 4),
#  ('brooche', 7),
#  ('pries', 2),
#  ('minis', 149),
#  ('rosemauve', 2),
#  ('printings', 2),
#  ('glittering', 13),
#  ('cop', 482),
#  ('voltagevvpower', 1),
#  ('bolan', 1),
#  ('greenolive', 1),
#  ('under', 2684),
#  ('environmentally', 12),
#  ('cuteperfect', 1),
#  ('paperbook', 1),
#  ('pcsuniversal', 1),
#  ('tourmilated', 1),
#  ('perspirant', 14),
#  ('icomfort', 1),
#  ('twd', 3),
#  ('underthemattress', 1),
#  ('pudding', 12),
#  ('pinksweetie', 1),
#  ('allergy', 57),
#  ('flightclub', 1),
#  ('leatherdetachable', 1),
#  ('laceup', 65),
#  ('duraline', 2),
#  ('abcs', 5),
#  ('prisoner', 1),
#  ('tivoli', 1),
#  ('outdoorready', 1),
#  ('fairway', 1),
#  ('pinkblack', 20),
#  ('prewash', 10),
#  ('perfumespraymist', 1),
#  ('votive', 18),
#  ('lydine', 1),
#  ('rigidity', 1),
#  ('amaro', 11),
#  ('himalayan', 8),
#  ('buckledown', 1),
#  ('relic', 10),
#  ('flyknits', 1),
#  ('housing', 18),
#  ('uvauvb', 21),
#  ('pillings', 8),
#  ('photo', 2615),
#  ('trufit', 1),
#  ('angledsponge', 1),
#  ('canvassaddle', 1),
#  ('sportswear', 21),
#  ('berrie', 68),
#  ('nightout', 4),
#  ('useful', 50),
#  ('alberto', 1),
#  ('sisley', 3),
#  ('wallets', 54),
#  ('admiring', 4),
#  ('spun', 36),
#  ('headrest', 5),
#  ('firmingsculpting', 2),
#  ('instrumental', 3),
#  ('juggling', 1),
#  ('pancake', 9),
#  ('pricethis', 2),
#  ('wirelessbluetooth', 1),
#  ('oncourt', 1),
#  ('selfexpressive', 1),
#  ('eddy', 132),
#  ('ultron', 5),
#  ('flamingos', 20),
#  ('omelets', 1),
#  ('sugarflour', 1),
#  ('twostep', 3),
#  ('royal', 358),
#  ('looped', 2),
#  ('inspecting', 5),
#  ('printer', 78),
#  ('airprominiminiminimini', 1),
#  ('itsy', 19),
#  ('lobelia', 1),
#  ('defense', 48),
#  ('fitwhats', 1),
#  ('greyed', 1),
#  ('roberto', 2),
#  ('cdquality', 1),
#  ('till', 5208),
#  ('brochae', 2),
#  ('stretcy', 1),
#  ('outputbluetooth', 1),
#  ('withsamsung', 2),
#  ('huuuge', 1),
#  ('formatavi', 1),
#  ('sweat', 2376),
#  ('palmolive', 3),
#  ('oi', 5841),
#  ('cashphone', 1),
#  ('irishgirl', 1),
#  ('tagwedding', 2),
#  ('isaac', 4),
#  ('swa', 1507),
#  ('meticulously', 2),
#  ('lsu', 16),
#  ('subscriptions', 2),
#  ('climacool', 18),
#  ('frice', 1),
#  ('forgetting', 6),
#  ('popcat', 1),
#  ('tanga', 11),
#  ('camoblack', 4),
#  ('expander', 2),
#  ('chromo', 1),
#  ('greyslate', 2),
#  ('adsorb', 2),
#  ('androgyny', 15),
#  ('dermelect', 1),
#  ('blesss', 1),
#  ('stocks', 36),
#  ('devin', 3),
#  ('filmstar', 2),
#  ('httpswwwlulufanaticscomitemlululemonruninspirecropiiallluxtremeheatheredberryyumyumblackgrape',
#   1),
#  ('foundationinfallible', 1),
#  ('showthrough', 3),
#  ('rmyou', 1),
#  ('pinkyorange', 1),
#  ('hipbone', 1),
#  ('smooth', 1024),
#  ('treason', 3),
#  ('ygrob', 1),
#  ('enjoys', 5),
#  ('corningware', 4),
#  ('donte', 2),
#  ('pathogens', 1),
#  ('allen', 79),
#  ('fluffiness', 2),
#  ('reestablish', 1),
#  ('ironedsteamed', 1),
#  ('plenty', 222),
#  ('sosflicker', 1),
#  ('caseprotects', 1),
#  ('rr', 8541),
#  ('itemswith', 4),
#  ('crawler', 3),
#  ('clovecedarwood', 1),
#  ('selftimer', 2),
#  ('chief', 32),
#  ('symmetry', 25),
#  ('daysplease', 2),
#  ('kirkland', 10),
#  ('glands', 3),
#  ('lagging', 1),
#  ('worned', 1),
#  ('wants', 61),
#  ('daisycorsets', 1),
#  ('marcos', 1),
#  ('incentives', 2),
#  ('pinups', 1),
#  ('grandmas', 11),
#  ('nutica', 1),
#  ('eyesthat', 1),
#  ('seventeen', 13),
#  ('stops', 22),
#  ('cheer', 103),
#  ('tagless', 9),
#  ('modelax', 1),
#  ('doubt', 54),
#  ('xboxone', 1),
#  ('peachyapricot', 1),
#  ('vitti', 19),
#  ('adventures', 32),
#  ('depart', 53),
#  ('monte', 14),
#  ('removalable', 1),
#  ('wheatbrown', 1),
#  ('backreally', 1),
#  ('leatherchain', 2),
#  ('selena', 28),
#  ('dangling', 24),
#  ('rmup', 4),
#  ('shorely', 1),
#  ('infants', 18),
#  ('businessman', 1),
#  ('gravitational', 1),
#  ('mineyours', 1),
#  ('blackfloral', 1),
#  ('comp', 3898),
#  ('hdd', 12),
#  ('makeupeye', 2),
#  ('jla', 4),
#  ('amie', 25),
#  ('antishine', 1),
#  ('petty', 1),
#  ('sultra', 2),
#  ('adorbs', 2),
#  ('receiptpaid', 1),
#  ('mccartney', 10),
#  ('eugene', 1),
#  ('her', 20000),
#  ('fitonce', 1),
#  ('starquest', 1),
#  ('cowabunga', 2),
#  ('brushcontouring', 1),
#  ('dentalgrade', 1),
#  ('mixmatch', 3),
#  ('warmed', 4),
#  ('nosenostril', 1),
#  ('bluegreenteal', 3),
#  ('managed', 8),
#  ('tanblueblack', 1),
#  ('conditionunbranded', 1),
#  ('brownluggage', 1),
#  ('martensmade', 1),
#  ('casualyeezy', 1),
#  ('typholsion', 1),
#  ('ponchoshawl', 1),
#  ('concelear', 2),
#  ('mymi', 2),
#  ('jeanology', 1),
#  ('hoard', 11),
#  ('swathes', 1),
#  ('graygreenblue', 1),
#  ('lana', 29),
#  ('imcludes', 1),
#  ('petplay', 1),
#  ('multitouch', 4),
#  ('nkjv', 1),
#  ('ecology', 1),
#  ('pendantschain', 1),
#  ('beene', 4),
#  ('cablescords', 1),
#  ('christ', 1320),
#  ('dashboard', 16),
#  ('vessesls', 1),
#  ('girlsboys', 2),
#  ('upart', 2),
#  ('jane', 110),
#  ('jacketits', 1),
#  ('wicking', 100),
#  ('resistant', 644),
#  ('selfie', 124),
#  ('phne', 4),
#  ('crafted', 189),
#  ('wrinkly', 29),
#  ('pairpcs', 1),
#  ('grea', 14307),
#  ('sellor', 1),
#  ('swimsexy', 1),
#  ('ru', 10921),
#  ('sexual', 7),
#  ('noticdarker', 2),
#  ('signsstands', 1),
#  ('triceps', 1),
#  ('lenghtunlined', 1),
#  ('trueplus', 1),
#  ('combodry', 1),
#  ('backround', 2),
#  ('blender', 237),
#  ('obsidianrose', 1),
#  ('nontarnish', 2),
#  ('ful', 9432),
#  ('coralwhite', 2),
#  ('demibuste', 2),
#  ('nflcarolina', 1),
#  ('rag', 2697),
#  ('hudson', 51),
#  ('directdrive', 1),
#  ('poseable', 3),
#  ('worn', 18190),
#  ('prebundled', 1),
#  ('shipsfree', 1),
#  ('clipped', 23),
#  ('markscratch', 1),
#  ('perry', 139),
#  ('graphite', 15),
#  ('mayu', 1),
#  ('tantastic', 2),
#  ('runners', 13),
#  ('venasaur', 1),
#  ('pungent', 1),
#  ('intents', 1),
#  ('reqoffers', 1),
#  ('cst', 55),
#  ('remotodo', 3),
#  ('rmwill', 2),
#  ('effortlessly', 32),
#  ('boosts', 19),
#  ('kundera', 1),
#  ('naga', 5),
#  ('viewer', 3),
#  ('barbecues', 2),
#  ('embroidering', 6),
#  ('stood', 4),
#  ('ironfist', 1),
#  ('valeria', 1),
#  ('pouring', 3),
#  ('purply', 1),
#  ('qualityimmediate', 4),
#  ('brushj', 2),
#  ('brights', 12),
#  ('converted', 4),
#  ('iditarod', 1),
#  ('stevia', 1),
#  ('lovenotjudge', 1),
#  ('saleing', 1),
#  ('herbalife', 11),
#  ('redgreen', 14),
#  ('man', 5062),
#  ('carbamide', 3),
#  ('brushstrokes', 1),
#  ('scales', 22),
#  ('picea', 1),
#  ('antideformation', 1),
#  ('dryprotect', 1),
#  ('pidgey', 2),
#  ('nespresso', 3),
#  ('flims', 13),
#  ('wcell', 1),
#  ('tgif', 1),
#  ('vermeer', 10),
#  ('typed', 1),
#  ('silvergrey', 5),
#  ('coupled', 2),
#  ('glazing', 4),
#  ('soworn', 1),
#  ('taffynew', 1),
#  ('heather', 403),
#  ('lcdcase', 1),
#  ('zeke', 1),
#  ('ghweblk', 1),
#  ('nickelodeons', 2),
#  ('bii', 3),
#  ('fitandflare', 3),
#  ('bundlebundlebundle', 1),
#  ('haile', 8),
#  ('aloha', 69),
#  ('shadows', 337),
#  ('malificent', 2),
#  ('frostmatte', 1),
#  ('deepv', 3),
#  ('camo', 318),
#  ('eyelashes', 246),
#  ('frolicking', 1),
#  ('consistanly', 1),
#  ('shax', 3),
#  ('pumpedused', 1),
#  ('freerazer', 1),
#  ('mclaughlinj', 1),
#  ('topsweatshirt', 1),
#  ('pinkluxe', 1),
#  ('stimulate', 37),
#  ('perlees', 1),
#  ('apricots', 1),
#  ('packagingopen', 1),
#  ('hereprice', 1),
#  ('magnolia', 28),
#  ('collapsable', 1),
#  ('bari', 5),
#  ('franchise', 4),
#  ('mewont', 1),
#  ('instagrammer', 3),
#  ('sooi', 1),
#  ('longhorns', 9),
#  ('stiff', 41),
#  ('graze', 1),
#  ('composition', 22),
#  ('spudger', 1),
#  ('cipher', 2),
#  ('mickeys', 8),
#  ('superjuicy', 1),
#  ('cacky', 1),
#  ('calabarmaroon', 1),
#  ('eur', 238),
#  ('humidifier', 13),
#  ('gluewaterproof', 1),
#  ('savon', 1),
#  ('scented', 279),
#  ('jacketpremium', 1),
#  ('greatestofalltime', 1),
#  ('poolswater', 1),
#  ('facets', 2),
#  ('kitsno', 2),
#  ('chloeml', 1),
#  ('ques', 4912),
#  ('nathaniel', 1),
#  ('yetis', 2),
#  ('ponds', 17),
#  ('unicef', 1),
#  ('handtowel', 1),
#  ('womena', 2),
#  ('uplifting', 12),
#  ('kitpls', 4),
#  ('alldaystay', 1),
#  ('blocke', 421),
#  ('zingo', 1),
#  ('rubs', 89),
#  ('raccoon', 21),
#  ('loosefit', 6),
#  ('niky', 1),
#  ('manufacturerunboxed', 2),
#  ('gopros', 1),
#  ('patternplain', 1),
#  ('blurays', 21),
#  ('samsungandroid', 2),
#  ('stunner', 4),
#  ('snide', 1),
#  ('eccentric', 4),
#  ('brave', 31),
#  ('shoppping', 3),
#  ('gods', 6),
#  ('jf', 16),
#  ('sweatershirt', 1),
#  ('fergie', 7),
#  ('needa', 1),
#  ('nonsmoke', 7),
#  ('tribals', 1),
#  ('switchover', 3),
#  ('mpink', 1),
#  ('crossword', 1),
#  ('nudeavailable', 1),
#  ('them', 4504),
#  ('crusher', 6),
#  ('horsehair', 1),
#  ('espirit', 3),
#  ('stylefashion', 1),
#  ('stylescolors', 1),
#  ('aguilar', 1),
#  ('niekro', 1),
#  ('rnca', 2),
#  ('labe', 651),
#  ('reccomend', 4),
#  ('wrestlemania', 1),
#  ('acup', 18),
#  ('swaddle', 60),
#  ('revere', 4),
#  ('foxowls', 1),
#  ('highbacked', 1),
#  ('drstrange', 1),
#  ('drug', 38),
#  ('seismic', 1),
#  ('summerfashion', 4),
#  ('latasha', 1),
#  ('drones', 2),
#  ('dterra', 18),
#  ('interest', 761),
#  ('delightful', 21),
#  ('marcella', 2),
#  ('paigekassner', 1),
#  ('okurr', 16),
#  ('tune', 114),
#  ('mirco', 2),
#  ('whitegrey', 15),
#  ('wim', 653),
#  ('yamaha', 1),
#  ('magista', 2),
#  ('zoraida', 1),
#  ('magentapurple', 1),
#  ('cease', 5),
#  ('stylelace', 1),
#  ('norway', 1),
#  ('pinkypeach', 6),
#  ('smuggle', 18),
#  ('eikoden', 1),
#  ('r', 138063),
#  ('rehabilitate', 1),
#  ('broadband', 4),
#  ('conditions', 423),
#  ('physcians', 2),
#  ('gothicretro', 1),
#  ('angrogyny', 1),
#  ('rims', 65),
#  ('spotlight', 18),
#  ('protectorxdry', 1),
#  ('tinkerbella', 1),
#  ('wamsutta', 1),
#  ('bogs', 5),
#  ('kpop', 48),
#  ('buffed', 6),
#  ('threads', 73),
#  ('across', 458),
#  ('housedress', 1),
#  ('cablecompatibilityiphone', 1),
#  ('when', 2839),
#  ('apparel', 385),
#  ('sucks', 5),
#  ('episode', 27),
#  ('availavle', 1),
#  ('barney', 5),
#  ('cari', 144),
#  ('noche', 1),
#  ('controllers', 113),
#  ('noelle', 3),
#  ('oddly', 3),
#  ('balansilk', 1),
#  ('battable', 1),
#  ('plantar', 3),
#  ('regarless', 1),
#  ('touches', 14),
#  ('dshwish', 1),
#  ('banilla', 1),
#  ('stringtags', 1),
#  ('doubling', 2),
#  ('his', 15387),
#  ('hairs', 118),
#  ('kelseylovesvs', 6),
#  ('coulture', 1),
#  ('gel', 1263),
#  ('polski', 1),
#  ('lenticular', 1),
#  ('glutenfree', 5),
#  ('rbl', 349),
#  ('reflection', 37),
#  ('recordable', 1),
#  ('picvery', 1),
#  ('chafing', 9),
#  ('greycream', 2),
#  ('itearphones', 1),
#  ('rechargeble', 1),
#  ('teezer', 1),
#  ('dualtube', 1),
#  ('steady', 24),
#  ('seemed', 13),
#  ('caddies', 3),
#  ('jewelorganizer', 1),
#  ('arvensisused', 1),
#  ('smarts', 5),
#  ('phonebut', 1),
#  ('lang', 107),
#  ('teaboth', 4),
#  ('resized', 5),
#  ('paranoid', 1),
#  ('manicurist', 1),
#  ('papo', 2),
#  ('eh', 692),
#  ('packageretail', 1),
#  ('dvdrdl', 1),
#  ('anothersellers', 2),
#  ('treatments', 37),
#  ('snack', 69),
#  ('mostly', 192),
#  ('nwtwomens', 1),
#  ('firme', 84),
#  ('satinlined', 1),
#  ('millimeterscase', 1),
#  ('adsorption', 19),
#  ('giovi', 1),
#  ('ultrapolling', 1),
#  ('heelflat', 1),
#  ('ozsealed', 1),
#  ('countertop', 6),
#  ('tyrosinase', 1),
#  ('tri', 6730),
#  ('nonnies', 1),
#  ('imd', 6),
#  ('position', 153),
#  ('setnwt', 1),
#  ('kwh', 174),
#  ('yuki', 3),
#  ('moduloks', 1),
#  ('newbubble', 1),
#  ('judge', 29),
#  ('wtag', 35),
#  ('aromafree', 1),
#  ('outfitsi', 1),
#  ('shaking', 5),
#  ('exodia', 2),
#  ('pipee', 2),
#  ('tantalizes', 1),
#  ('marion', 2),
#  ('carnegie', 1),
#  ('playdoze', 1),
#  ('ambroxan', 1),
#  ('organizersholdersstorage', 1),
#  ('brandroamans', 1),
#  ('sundried', 1),
#  ('purchasel', 2),
#  ('topgreat', 1),
#  ('thanx', 3),
#  ('discussing', 1),
#  ('ands', 1673),
#  ('glistening', 3),
#  ('daiquiries', 1),
#  ('shaquille', 1),
#  ('mattesatin', 6),
#  ('reheat', 3),
#  ('wristlet', 322),
#  ('bai', 106),
#  ('homework', 15),
#  ('beccas', 1),
#  ('cardigansize', 1),
#  ('importance', 7),
#  ('thatthere', 2),
#  ('dayton', 3),
#  ('skelington', 1),
#  ('woodsign', 1),
#  ('stainskept', 1),
#  ('toei', 1),
#  ('sit', 2915),
#  ('slims', 17),
#  ('america', 1646),
#  ('hellosanrio', 2),
#  ('vane', 8),
#  ('garter', 51),
#  ('punkydoodle', 4),
#  ('guaranteedthis', 3),
#  ('makeupfoundation', 4),
#  ('mcnamara', 1),
#  ('daytomight', 1),
#  ('political', 2),
#  ('pf', 377),
#  ('healsz', 1),
#  ('appox', 3),
#  ('airpods', 5),
#  ('fintastic', 1),
#  ('tian', 165),
#  ('boda', 1),
#  ('mouchette', 1),
#  ('griddler', 2),
#  ('jurassic', 9),
#  ('waterproofprimerbasesuper', 1),
#  ('flashes', 12),
#  ('wicked', 14),
#  ('kimoji', 12),
#  ('meshtummy', 1),
#  ('springespecially', 1),
#  ('salegood', 1),
#  ('usedsold', 1),
#  ('brandapple', 1),
#  ('bagcarrying', 1),
#  ('absolut', 629),
#  ('upthis', 1),
#  ('restitch', 7),
#  ('magcon', 1),
#  ('includingx', 2),
#  ('doorway', 4),
#  ('angler', 42),
#  ('servicehonest', 1),
#  ('thumbstick', 6),
#  ('jandals', 1),
#  ('swisher', 2),
#  ('ahhmaaziingg', 1),
#  ('bought', 3175),
#  ('sensationalfull', 1),
#  ('shadowsponge', 1),
#  ('josefina', 1),
#  ('ibd', 3),
#  ('bootsponcho', 1),
#  ('mizrahi', 3),
#  ('poughkeepsie', 1),
#  ('personmatch', 1),
#  ('braced', 3),
#  ('crystalsband', 1),
#  ('posed', 207),
#  ('pez', 49),
#  ('heffalump', 4),
#  ('liquorice', 1),
#  ('laptop', 381),
#  ('ipads', 26),
#  ('ongoing', 3),
#  ('lipcare', 1),
#  ('fact', 1136),
#  ('gripadded', 1),
#  ('bloch', 2),
#  ('eyelinerhighlighter', 1),
#  ('eyelining', 1),
#  ('tcl', 57),
#  ('dsuper', 7)]
