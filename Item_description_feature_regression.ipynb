# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.api.types import CategoricalDtype
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import Ridge

print(pd.__version__)

# %matplotlib inline
# Out:
# 0.22.0

# %%
# Read table

mercari_data = pd.read_table("./train.tsv", index_col = 'train_id', dtype = {'item_condition_id':CategoricalDtype(categories = [str(i) for i in range(1,6)], ordered = True), 'category_name':'category', 'brand_name': 'category', 'shipping':'category'})
# Out:
# /Users/Abe/anaconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py:466: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
cat1, cat2, cat3, a = mercari_data.category_name.str.split("/", 3).str
mercari_data['category_1'] = cat1
mercari_data['category_2'] = cat2
mercari_data['category_3'] = cat3
for col in ['category_1', 'category_2', 'category_3']:
    mercari_data[col] = mercari_data[col].astype('category')

# %%
mercari_data['log_price'] = np.log(mercari_data.price + 1)

# %%
mercari_data[(mercari_data['category_1'] == 'Men') & (mercari_data['category_2'] == 'Tops') & (mercari_data['category_3'] == 'T-shirts')].head(10)
# Out:
#                                              name item_condition_id  \
# train_id
# 0             MLB Cincinnati Reds T Shirt Size XL                 3
# 78                                    Trump Shirt                 3
# 151       Nike men's dri-fit sleeveless shirt tee                 3
# 350              Stussy vintage dot Ragland LARGE                 1
# 352          2-Mens XXL Cruise Ship T-Shirts NWOT                 2
# 432                                 'Garbage" tee                 3
# 497            Nintendo 64 Men's T shirt Size 2XL                 1
# 660                            Undefeated T-Shirt                 2
# 1357                                    Huf Shirt                 2
# 1408                             Men's Nike shirt                 3
#
#               category_name  brand_name  price shipping  \
# train_id
# 0         Men/Tops/T-shirts         NaN   10.0        1
# 78        Men/Tops/T-shirts         NaN    9.0        0
# 151       Men/Tops/T-shirts        Nike   14.0        0
# 350       Men/Tops/T-shirts         NaN   33.0        0
# 352       Men/Tops/T-shirts         NaN    9.0        0
# 432       Men/Tops/T-shirts         NaN    7.0        1
# 497       Men/Tops/T-shirts    Nintendo   15.0        1
# 660       Men/Tops/T-shirts  Undefeated   19.0        0
# 1357      Men/Tops/T-shirts         HUF   22.0        0
# 1408      Men/Tops/T-shirts        Nike   34.0        0
#
#                                            item_description category_1  \
# train_id
# 0                                        No description yet        Men
# 78                    Worn once; will be washed before sent        Men
# 151       This is a men's Nike dri-fit shirt which is bl...        Men
# 350                      Brand new with tags white/burgundy        Men
# 352       2-Mens XXL Cruise Ship T-Shirts. Grey-Royal Ca...        Men
# 432       A black tee with white screen print g and garb...        Men
# 497          New t shirt Official Licensed Product Size 2XL        Men
# 660        Like new condition Quality material Staple piece        Men
# 1357      Basically brand new. No wear or tear, great co...        Men
# 1408      Men's Nike shirt. Black . Used once, can barel...        Men
#
#          category_2 category_3  log_price
# train_id
# 0              Tops   T-shirts   2.397895
# 78             Tops   T-shirts   2.302585
# 151            Tops   T-shirts   2.708050
# 350            Tops   T-shirts   3.526361
# 352            Tops   T-shirts   2.302585
# 432            Tops   T-shirts   2.079442
# 497            Tops   T-shirts   2.772589
# 660            Tops   T-shirts   2.995732
# 1357           Tops   T-shirts   3.135494
# 1408           Tops   T-shirts   3.555348

# %%
data_subset = mercari_data[(mercari_data['category_1'] == 'Men') & (mercari_data['category_2'] == 'Tops') & (mercari_data['category_3'] == 'T-shirts')]
print(data_subset['item_description'].count())

data_subset = data_subset[data_subset['item_description'] != 'No description yet']
print(data_subset['item_description'].count())
# Out:
# 15108
# 13851

# %%
vectorizer = CountVectorizer(stop_words="english", binary = True, min_df = 50)
transformed = vectorizer.fit_transform(data_subset['item_description'])
sparse_sums = transformed.sum(axis = 0)
feature_names = vectorizer.get_feature_names()
sorted_word_counts = sorted(zip(feature_names, sparse_sums.tolist()[0]), key = lambda x: x[1], reverse = True)

# %%
reg = Ridge(alpha=.1)
reg.fit(transformed, data_subset['log_price'])
sorted(zip(feature_names, sparse_sums.tolist()[0], reg.coef_.tolist()), key = lambda x: x[2], reverse = True)
# Out:
# [('important', 80, 0.4675150106551865),
#  ('bag', 214, 0.4585050919396132),
#  ('ape', 74, 0.4523779001405798),
#  ('gucci', 73, 0.4469280795419409),
#  ('fighter', 52, 0.4443005035924868),
#  ('authentic', 488, 0.43845012010254314),
#  ('limited', 59, 0.405036284100835),
#  ('hoodie', 52, 0.3571600811533232),
#  ('supreme', 328, 0.343638702278222),
#  ('odd', 61, 0.3414014259449272),
#  ('rare', 127, 0.326787500609027),
#  ('religion', 76, 0.30714302637340246),
#  ('tshirts', 91, 0.2994836365991043),
#  ('jersey', 84, 0.2841664320122767),
#  ('patagonia', 54, 0.2727012548845682),
#  ('affliction', 112, 0.2660557117592134),
#  ('description', 54, 0.24943998758560787),
#  ('shirts', 925, 0.2468695586580725),
#  ('10', 244, 0.2452562936577449),
#  ('jacket', 64, 0.24453627897305152),
#  ('vineyard', 99, 0.23671770527207875),
#  ('shorts', 62, 0.23348771707032243),
#  ('asap', 54, 0.23046839391886087),
#  ('lot', 155, 0.22120120399621018),
#  ('tees', 120, 0.21352964575568176),
#  ('runs', 106, 0.20344942738299693),
#  ('fits', 587, 0.19690897764871457),
#  ('nwt', 273, 0.1956670078910053),
#  ('polo', 441, 0.18323451949550168),
#  ('thrasher', 161, 0.1822531263048795),
#  ('sold', 115, 0.18129323831041116),
#  ('retails', 75, 0.1783094651374756),
#  ('usa', 88, 0.17423016672087765),
#  ('interested', 64, 0.16727344180497816),
#  ('armpit', 75, 0.1665731018173764),
#  ('metallica', 57, 0.16095092731562316),
#  ('available', 273, 0.15915172913700634),
#  ('24', 83, 0.1583786061766745),
#  ('harley', 118, 0.15762936084340148),
#  ('looking', 142, 0.15435214088184557),
#  ('offers', 243, 0.15287461529577684),
#  ('tried', 54, 0.15124033952900331),
#  ('feel', 210, 0.147551609489293),
#  ('sz', 167, 0.14705677303974096),
#  ('stussy', 143, 0.14626354907650435),
#  ('class', 60, 0.14586020198640756),
#  ('includes', 79, 0.14435814231253546),
#  ('comes', 269, 0.14239765289552705),
#  ('bape', 250, 0.14171292384666484),
#  ('merch', 63, 0.1412631871378804),
#  ('offer', 133, 0.13947841630867466),
#  ('brandy', 50, 0.1379338485702606),
#  ('tie', 83, 0.1365073155362703),
#  ('message', 165, 0.13615858865735928),
#  ('firm', 496, 0.13590792677430885),
#  ('official', 78, 0.13577815458634862),
#  ('wrong', 66, 0.13274084575440287),
#  ('new', 3768, 0.1267350756393438),
#  ('set', 61, 0.12239479589428136),
#  ('southern', 86, 0.11945723616486406),
#  ('tour', 179, 0.1192659097956831),
#  ('shop', 51, 0.11842440126504986),
#  ('come', 142, 0.11764882641048097),
#  ('sell', 182, 0.11742867379322201),
#  ('29', 65, 0.11717118628095917),
#  ('pit', 115, 0.11527268276232033),
#  ('usps', 118, 0.11324366719193736),
#  ('piece', 69, 0.11231178214789866),
#  ('box', 73, 0.11032103140042095),
#  ('100', 746, 0.10741918303920019),
#  ('buckle', 58, 0.10609112330670839),
#  ('contact', 107, 0.10434837472767866),
#  ('mind', 52, 0.10256157653612902),
#  ('selling', 156, 0.10206522033738),
#  ('long', 765, 0.1016321931710467),
#  ('tommy', 169, 0.1006309762206065),
#  ('day', 292, 0.09761133698644964),
#  ('quality', 138, 0.09509042093177206),
#  ('double', 59, 0.09341583316062854),
#  ('really', 143, 0.09310361695540975),
#  ('brands', 60, 0.09048123958831725),
#  ('brown', 73, 0.09031247216544472),
#  ('lightly', 94, 0.08993341320875588),
#  ('button', 65, 0.08833659395029174),
#  ('original', 172, 0.08807817588059844),
#  ('bundle', 842, 0.08752455553228325),
#  ('40', 57, 0.08598896516559373),
#  ('dry', 66, 0.08286802208270008),
#  ('shoulder', 98, 0.08079028518572247),
#  ('rm', 820, 0.08037075296726999),
#  ('boys', 73, 0.08021529872776972),
#  ('bought', 284, 0.07972291036437994),
#  ('diamond', 141, 0.07936772799218031),
#  ('fast', 136, 0.07654088561133873),
#  ('brand', 2127, 0.07531862109199686),
#  ('fit', 685, 0.07357906777586781),
#  ('hand', 75, 0.07047889675267804),
#  ('want', 171, 0.07017216950277083),
#  ('sizing', 54, 0.06997227272367688),
#  ('crew', 115, 0.06910985489155103),
#  ('smaller', 81, 0.06812036085547385),
#  ('feedback', 88, 0.06783375629185204),
#  ('listing', 172, 0.06741955148804868),
#  ('perfect', 356, 0.06592648978667062),
#  ('pictures', 154, 0.06504925540318637),
#  ('regular', 55, 0.06429570021857589),
#  ('50', 67, 0.06297018100506144),
#  ('just', 453, 0.06274408891533023),
#  ('logo', 493, 0.06218680389024852),
#  ('negotiable', 105, 0.06165089203000303),
#  ('bleached', 69, 0.059478749913188717),
#  ('urban', 104, 0.05871251880265226),
#  ('days', 175, 0.05831531294807997),
#  ('deal', 103, 0.05792635848615056),
#  ('flat', 53, 0.057919841432693076),
#  ('palace', 90, 0.057659745545976755),
#  ('didn', 57, 0.057534294060124634),
#  ('punk', 53, 0.056113556521473575),
#  ('smoke', 588, 0.05588994357607754),
#  ('minor', 73, 0.054331475190614896),
#  ('wash', 123, 0.05350560263872865),
#  ('pocket', 168, 0.05305747232197682),
#  ('twice', 200, 0.052986416605134354),
#  ('3x', 58, 0.05293971274160459),
#  ('women', 234, 0.0523604840799512),
#  ('vines', 95, 0.05221357494520959),
#  ('priced', 106, 0.05194590407267846),
#  ('fox', 58, 0.05105309951435516),
#  ('left', 158, 0.05076937150674223),
#  ('retail', 172, 0.0504219352028371),
#  ('purple', 92, 0.049088880109325765),
#  ('light', 257, 0.04844663305675516),
#  ('pet', 231, 0.046114409156014),
#  ('price', 824, 0.04573261323309811),
#  ('clean', 142, 0.04549815003598736),
#  ('don', 216, 0.044040096990183034),
#  ('better', 60, 0.04230288016660125),
#  ('vintage', 528, 0.04228846758384574),
#  ('kanye', 63, 0.041935482194642264),
#  ('barely', 114, 0.041142503331719676),
#  ('sale', 151, 0.04103734102372096),
#  ('sleeved', 59, 0.04069631926093664),
#  ('high', 124, 0.040149541211019685),
#  ('plus', 62, 0.03988111127267651),
#  ('signs', 119, 0.03950027133470271),
#  ('white', 866, 0.039296052548528644),
#  ('know', 154, 0.03855401026554909),
#  ('pink', 231, 0.03805522416765006),
#  ('pic', 104, 0.03792445021927796),
#  ('pacsun', 86, 0.037121618369356124),
#  ('bundles', 121, 0.03695991922836834),
#  ('heavy', 65, 0.03643106328060721),
#  ('different', 146, 0.036154173072582486),
#  ('ll', 63, 0.03559016881985542),
#  ('xl', 1672, 0.03373529562775456),
#  ('rips', 394, 0.03248566492620972),
#  ('doesn', 69, 0.03215184306423845),
#  ('need', 88, 0.03166289678939343),
#  ('concert', 83, 0.031602591984667874),
#  ('30', 93, 0.03127276704015153),
#  ('distressed', 75, 0.03083398581714639),
#  ('world', 67, 0.03077363848211543),
#  ('25', 58, 0.02974913393260046),
#  ('star', 83, 0.028712080777755337),
#  ('xs', 122, 0.028512678013795638),
#  ('open', 63, 0.028134017364163905),
#  ('tank', 68, 0.027677470259920227),
#  ('custom', 89, 0.026214623293415402),
#  ('big', 157, 0.025651504251625542),
#  ('colors', 138, 0.02394974328277818),
#  ('cracking', 111, 0.023815344408389016),
#  ('super', 290, 0.02377199525845637),
#  ('3xl', 190, 0.02344783909221338),
#  ('gold', 74, 0.02315608809580319),
#  ('non', 54, 0.022651930625580078),
#  ('sure', 73, 0.02191211822029577),
#  ('letters', 60, 0.021831728056217716),
#  ('bad', 75, 0.021620686482731723),
#  ('forever', 88, 0.020142295257411923),
#  ('buy', 144, 0.020121312875924797),
#  ('flag', 51, 0.01978452133023033),
#  ('rate', 64, 0.01869089623080166),
#  ('23', 54, 0.01860755390023541),
#  ('right', 90, 0.0182218910540829),
#  ('screen', 66, 0.017875322292384664),
#  ('neck', 367, 0.017734988757817465),
#  ('details', 65, 0.016296434480291697),
#  ('hem', 71, 0.015925507201895436),
#  ('dead', 75, 0.015575529663403807),
#  ('printed', 82, 0.01544840272790988),
#  ('ship', 413, 0.014408359043091514),
#  ('sleeve', 1006, 0.014119878373957869),
#  ('tags', 1448, 0.013101062914831067),
#  ('calvin', 66, 0.01264523172767076),
#  ('nwot', 178, 0.012131969744371142),
#  ('reasonable', 63, 0.0119628077160545),
#  ('listed', 82, 0.011685498558280466),
#  ('guess', 76, 0.011618543611409269),
#  ('store', 73, 0.011521614483736772),
#  ('color', 986, 0.010757116239593413),
#  ('check', 446, 0.010726100264470257),
#  ('style', 186, 0.01030842634901722),
#  ('baseball', 88, 0.010243288903033554),
#  ('length', 190, 0.00920611182472094),
#  ('shown', 95, 0.007369248066807396),
#  ('package', 76, 0.007033404718739899),
#  ('comfy', 74, 0.005366476710658348),
#  ('tears', 257, 0.004723636431998447),
#  ('awesome', 217, 0.004650590297335829),
#  ('xxl', 406, 0.0046063162346804505),
#  ('does', 66, 0.00439870990033088),
#  ('christmas', 58, 0.003717004870011571),
#  ('red', 475, 0.0029750543266361044),
#  ('bit', 56, 0.0025132469750418903),
#  ('classic', 123, 0.0024468079501676417),
#  ('pictured', 50, 0.0020848015233188005),
#  ('couple', 180, 0.0020278898549505623),
#  ('28', 60, 0.0019697159340727856),
#  ('athletic', 90, 0.0018672157400157327),
#  ('item', 257, 0.0005218981479172987),
#  ('looks', 163, 0.00037097021444516045),
#  ('black', 1402, 0.00027488965075520624),
#  ('tag', 562, -0.00010069410877341064),
#  ('look', 160, -0.00014402658413784696),
#  ('shape', 163, -0.00038984649619724725),
#  ('huf', 53, -0.0006773285587097712),
#  ('originally', 112, -0.0011149133871729672),
#  ('print', 221, -0.002120669263941311),
#  ('noticeable', 80, -0.002266370101923654),
#  ('yellow', 166, -0.0030851603360868185),
#  ('90s', 62, -0.00332001205850822),
#  ('thanks', 141, -0.003586332638310285),
#  ('medium', 2167, -0.003648629755067236),
#  ('small', 1708, -0.0037150443625063086),
#  ('27', 53, -0.004043086799150905),
#  ('best', 65, -0.004727281437079024),
#  ('maroon', 61, -0.004861971854053403),
#  ('tee', 1350, -0.004959772564357885),
#  ('club', 60, -0.004968971372162602),
#  ('green', 332, -0.005162048706605175),
#  ('extra', 203, -0.005333009805784475),
#  ('low', 91, -0.006649519080056769),
#  ('lauren', 236, -0.006959562592197254),
#  ('state', 51, -0.007412895350957679),
#  ('size', 6102, -0.007855832106123577),
#  ('great', 1440, -0.007856774449993168),
#  ('listings', 264, -0.008435167607640676),
#  ('anymore', 56, -0.008681130697541024),
#  ('true', 203, -0.008977156826632166),
#  ('basketball', 54, -0.009431815144079798),
#  ('2xl', 332, -0.009873812868883558),
#  ('got', 105, -0.010908380860630385),
#  ('photo', 70, -0.011180498349180517),
#  ('orders', 79, -0.011198925934115079),
#  ('used', 609, -0.011515591551088876),
#  ('slight', 106, -0.01236562197543455),
#  ('preshrunk', 58, -0.01273836995563093),
#  ('times', 488, -0.013547877466915033),
#  ('large', 2393, -0.013561837992163712),
#  ('dri', 79, -0.014248994340637762),
#  ('nike', 722, -0.015249426693502368),
#  ('fabric', 57, -0.01647006117568755),
#  ('washed', 296, -0.017501723347831493),
#  ('purchased', 140, -0.01765096235633504),
#  ('american', 348, -0.017785505981228692),
#  ('21', 169, -0.018490407823554714),
#  ('items', 518, -0.019603073304150866),
#  ('deals', 70, -0.019656668544356985),
#  ('buying', 131, -0.020415229409521295),
#  ('measurements', 117, -0.021435878556949905),
#  ('short', 416, -0.022299698310798678),
#  ('business', 98, -0.02269434472266296),
#  ('old', 91, -0.02478070724884551),
#  ('eagle', 200, -0.02532624614045224),
#  ('express', 76, -0.02559437038131806),
#  ('time', 165, -0.026309711503429676),
#  ('abercrombie', 83, -0.026777939612989285),
#  ('sun', 63, -0.026846338985185403),
#  ('blue', 898, -0.029136688368190045),
#  ('ask', 391, -0.030543072049488803),
#  ('embroidered', 67, -0.0307499932093851),
#  ('condition', 3409, -0.030926784010625312),
#  ('excellent', 467, -0.031294588160826156),
#  ('graphics', 88, -0.03171852878609502),
#  ('camo', 79, -0.03219857057625237),
#  ('nice', 255, -0.03236726861137437),
#  ('final', 61, -0.03343795999767975),
#  ('adult', 214, -0.033592942853499376),
#  ('team', 57, -0.03468425223520197),
#  ('med', 74, -0.03479898614616396),
#  ('slim', 72, -0.03543202496021617),
#  ('gray', 375, -0.03648533643183556),
#  ('worn', 2574, -0.03665092408202777),
#  ('chest', 154, -0.038452758774087915),
#  ('wore', 163, -0.03848026722407078),
#  ('picture', 178, -0.03858504281683386),
#  ('sleeves', 255, -0.03917633595004421),
#  ('fair', 53, -0.03923571037242649),
#  ('2x', 79, -0.03929167313934546),
#  ('unisex', 384, -0.03929640720742402),
#  ('love', 85, -0.03953637693685352),
#  ('20', 58, -0.0403766236705339),
#  ('jordan', 184, -0.0411706550095821),
#  ('cool', 150, -0.04122457946657246),
#  ('included', 82, -0.041480913254527345),
#  ('exclusive', 79, -0.04185636427623227),
#  ('navy', 390, -0.04252875914012352),
#  ('thermal', 52, -0.0428832090248194),
#  ('husband', 53, -0.043035968299830314),
#  ('shipping', 1249, -0.043375465199486506),
#  ('collar', 113, -0.0437515356410401),
#  ('comfortable', 92, -0.04379101844361207),
#  ('god', 52, -0.04380889078930391),
#  ('flaws', 430, -0.04460642746102428),
#  ('pics', 65, -0.0452528438111223),
#  ('davidson', 93, -0.045877681579658346),
#  ('good', 1395, -0.04670544782445747),
#  ('dc', 51, -0.04739520432104365),
#  ('like', 1213, -0.04760393660174699),
#  ('little', 178, -0.04897773627714981),
#  ('closet', 175, -0.048982728955165665),
#  ('music', 76, -0.04903532272567807),
#  ('grey', 385, -0.04917356187582413),
#  ('jeans', 79, -0.04993809102428786),
#  ('stains', 837, -0.04998787617320908),
#  ('nfl', 62, -0.05078679707623876),
#  ('thank', 126, -0.05108068026150598),
#  ('graphic', 296, -0.05179700428228608),
#  ('purchase', 134, -0.05237010201640984),
#  ('seen', 55, -0.052811435859300766),
#  ('page', 56, -0.05352305314218543),
#  ('read', 120, -0.05421529343825995),
#  ('klein', 67, -0.05614013631174317),
#  ('soft', 324, -0.05679079256363339),
#  ('nautica', 57, -0.057089888975809674),
#  ('hot', 188, -0.05757135892629988),
#  ('life', 120, -0.05770797816914803),
#  ('let', 137, -0.058120028386990395),
#  ('questions', 364, -0.058312963018640876),
#  ('slightly', 58, -0.05859636115048831),
#  ('holes', 408, -0.058735118823106426),
#  ('design', 197, -0.05983272603028371),
#  ('men', 2939, -0.06110025484923417),
#  ('owned', 64, -0.06159816469902526),
#  ('maybe', 68, -0.06245686993422983),
#  ('material', 222, -0.06256820707029027),
#  ('measures', 69, -0.0625796732675664),
#  ('gift', 94, -0.06302551942744299),
#  ('polyester', 136, -0.06324994509541532),
#  ('future', 70, -0.06466561999357975),
#  ('multiple', 111, -0.06472099196031854),
#  ('rock', 114, -0.06557621804442271),
#  ('tiny', 56, -0.06744534922813893),
#  ('hurley', 94, -0.06772992633640938),
#  ('north', 80, -0.06887260455052517),
#  ('heather', 56, -0.06948768007215991),
#  ('supply', 93, -0.07037179213367317),
#  ('man', 85, -0.07056738998598),
#  ('gently', 179, -0.07466721336465956),
#  ('fading', 220, -0.07597641436563614),
#  ('hardly', 55, -0.07623721084431455),
#  ('orange', 146, -0.0762647076213504),
#  ('iron', 53, -0.07694665459143493),
#  ('prices', 172, -0.07696473083901788),
#  ('air', 79, -0.08093117282530418),
#  ('pre', 81, -0.0813385293107307),
#  ('inches', 143, -0.08221556950032262),
#  ('york', 50, -0.08359976180669233),
#  ('asking', 73, -0.0843215163611593),
#  ('champion', 72, -0.08436139923923651),
#  ('cute', 98, -0.08436683454216348),
#  ('shirt', 4953, -0.08462214049035302),
#  ('band', 274, -0.08509412539410437),
#  ('wars', 53, -0.08582965876208715),
#  ('says', 153, -0.0870389780673039),
#  ('shipped', 79, -0.08850520311422921),
#  ('change', 73, -0.08863302313097197),
#  ('plain', 70, -0.08865531321259507),
#  ('make', 212, -0.0887328110764715),
#  ('euc', 64, -0.08916256230491192),
#  ('wear', 444, -0.09277822741329375),
#  ('reebok', 52, -0.09357644248262766),
#  ('adidas', 354, -0.09395169859912719),
#  ('order', 120, -0.09478918025240315),
#  ('free', 1589, -0.0949828404606054),
#  ('hollister', 213, -0.09532199039391927),
#  ('clothing', 74, -0.09547921546226855),
#  ('mens', 635, -0.09749051093481315),
#  ('cotton', 784, -0.09769785851687443),
#  ('zumiez', 59, -0.09864067752057534),
#  ('dark', 207, -0.09899732288553618),
#  ('pretty', 58, -0.09918991937228991),
#  ('aeropostale', 58, -0.09922527484408812),
#  ('hole', 103, -0.10197497075194024),
#  ('ready', 101, -0.10304685856816939),
#  ('sizes', 394, -0.10365021148669509),
#  ('product', 55, -0.10381407062471756),
#  ('comment', 173, -0.10561083395587771),
#  ('topic', 168, -0.10618590381886084),
#  ('apparel', 120, -0.10745404033743146),
#  ('happy', 50, -0.10781889920424269),
#  ('discounts', 116, -0.11148845516469574),
#  ('shows', 54, -0.11192547345785066),
#  ('nba', 69, -0.11245933092595381),
#  ('ships', 126, -0.11279377362203415),
#  ('lettering', 72, -0.1128959897012291),
#  ('weight', 55, -0.11363910171995154),
#  ('faded', 164, -0.11524265271368501),
#  ('hilfiger', 125, -0.11921198923471495),
#  ('outfitters', 104, -0.12475463066393513),
#  ('willing', 67, -0.12511697360798693),
#  ('home', 602, -0.12630094692116894),
#  ('stain', 110, -0.1291395070892858),
#  ('disney', 61, -0.13234181881209983),
#  ('cut', 129, -0.14264402493147382),
#  ('tshirt', 641, -0.14417998410649485),
#  ('vans', 134, -0.14782704045428255),
#  ('retro', 108, -0.14797447358478563),
#  ('face', 95, -0.14856488977054855),
#  ('say', 59, -0.15155462344225284),
#  ('sport', 59, -0.15313910913449372),
#  ('gildan', 82, -0.1553104524375231),
#  ('dye', 88, -0.1684291536634403),
#  ('unless', 123, -0.17030542916622854),
#  ('obey', 75, -0.17291595693374515),
#  ('ralph', 238, -0.17322362738513677),
#  ('holds', 55, -0.18726226892102507),
#  ('12', 59, -0.1907075199653987),
#  ('save', 317, -0.19924162726196026),
#  ('michael', 50, -0.20327666315974832),
#  ('lots', 60, -0.21884891264832163),
#  ('clothes', 80, -0.22338665374225303),
#  ('use', 78, -0.22394254939981081),
#  ('discount', 58, -0.24299205963678946),
#  ('leave', 98, -0.24695514357649473),
#  ('mail', 56, -0.3159825243738992),
#  ('yeezy', 131, -0.3338910164347632),
#  ('leaving', 82, -0.3485256988460796),
#  ('bathing', 73, -0.3716125915056402)]

# %%
# Do try experimenting with alpha.  Keep the variance and bias within reason

# Now it's time to decide which featuresd (words) you want to look at.
# Don't choose words like stop-words, which are really common (but appear not to be
# in your vocaubulary anyway since you took them out in the default
# preprocessor) but also don't choose words that don't appear much
# Feb 9 - right now I'm just changing min_df in CountVectorizer to set that threshold, nothing
# complicated like in sklearn.feature_selection

# In addition to the minimum threshold, you can use some module from
# sklearn.feature_selection, like sklearn.feature_selection.mutual_info_regression
# to decide which words actually matter.

# the sklearn website has a good example on the feature_selection tools
# and compares the results of one to SVM weights

# Feb 9 - you looked at ridge regression for various minimum occurence thresholds and alphas (regularization constant),
# and the coeficients (accesible with Ridge.coef_ (a numpy.ndarray)) barely changed at all,
# suggesting that cross-correlation is not an issue with regression.  Now I'm seeing if this is true by
# trying a sparse principal components analysis to see explicitly (if this is possible) whether certain words
# are related - left off trying to figure out what alpha and ridge_alpha meant in sklearn's implementation of
# Sparse PCA, and then wondering if I should use SVD decomposition, part of latent semantic analysis, instead, reading
# http://scikit-learn.org/stable/modules/decomposition.html#sparsepca
# The good news about sparse PCA is that it imposes a restriction, k on Wikipedia, on the number of
# variables that can use used in any component, creating a much smaller number of coefficients on the loading vectors

# At the end of the day, you may not need PCA and decomposition techniques, if you are willing to assume that
# the amount of covariance of the features is low.  This is plausible since the item descriptions are so short.
# If this is the case, looking at the coeffieicents of features in OLS would be a good starting point.
# Then you could look at particular documents (item descriptions) and see if there could be any interactions

# The reason I am starting out with linear regression (including ridge regression)
# Is that those models are easier to interpret.  Perhaps after tuning a linear regression I can
# combine it with less interpretable models
