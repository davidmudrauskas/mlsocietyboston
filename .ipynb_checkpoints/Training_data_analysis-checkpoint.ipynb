# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.api.types import CategoricalDtype
import scipy.stats as stats
import statsmodels.formula.api as sm

print(pd.__version__)

# %matplotlib inline
# Out:
# 0.22.0

# %%
# Read table

train_df = pd.read_table("./train.tsv", index_col = 'train_id', dtype = {'item_condition_id':CategoricalDtype(categories = [str(i) for i in range(1,6)], ordered = True), 'category_name':'category', 'brand_name': 'category', 'shipping':'category'})
# Out:
# /Users/Abe/anaconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py:466: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
# Create columns for the first three hierarchical levels represented in the category name column.
# Levels greater than one contain the names of the parent levels with the current level, separeated by slashes

a, b, c, d = train_df['category_name'].str.split("/", 3).str
category_oneLevel = a
category_twoLevel = a + "/" + b
category_threeLevel = a + "/" + b + "/" + c
train_df['category_oneLevel'] = category_oneLevel
train_df['category_twoLevel'] = category_twoLevel
train_df['category_threeLevel'] = category_threeLevel
for col in ['category_oneLevel', 'category_twoLevel', 'category_threeLevel']:
    train_df[col] = train_df[col].astype('category')

# %%
# The categories of the first category level

for i in train_df.category_oneLevel.cat.categories.values:
    print(i)
# Out:
# Beauty
# Electronics
# Handmade
# Home
# Kids
# Men
# Other
# Sports & Outdoors
# Vintage & Collectibles
# Women

# %%
# The path of each category in the second level

for i in train_df.category_twoLevel.cat.categories.values:
    print(i)
# Out:
# Beauty/Bath & Body
# Beauty/Fragrance
# Beauty/Hair Care
# Beauty/Makeup
# Beauty/Other
# Beauty/Skin Care
# Beauty/Tools & Accessories
# Electronics/Cameras & Photography
# Electronics/Car Audio, Video & GPS
# Electronics/Cell Phones & Accessories
# Electronics/Computers & Tablets
# Electronics/Media
# Electronics/Other
# Electronics/TV, Audio & Surveillance
# Electronics/Video Games & Consoles
# Handmade/Accessories
# Handmade/Art
# Handmade/Bags and Purses
# Handmade/Books and Zines
# Handmade/Candles
# Handmade/Ceramics and Pottery
# Handmade/Children
# Handmade/Clothing
# Handmade/Crochet
# Handmade/Dolls and Miniatures
# Handmade/Furniture
# Handmade/Geekery
# Handmade/Glass
# Handmade/Holidays
# Handmade/Housewares
# Handmade/Jewelry
# Handmade/Knitting
# Handmade/Music
# Handmade/Needlecraft
# Handmade/Other
# Handmade/Others
# Handmade/Paper Goods
# Handmade/Patterns
# Handmade/Pets
# Handmade/Quilts
# Handmade/Toys
# Handmade/Weddings
# Handmade/Woodworking
# Home/Artwork
# Home/Bath
# Home/Bedding
# Home/Cleaning Supplies
# Home/Furniture
# Home/Home Appliances
# Home/Home Décor
# Home/Kids' Home Store
# Home/Kitchen & Dining
# Home/Other
# Home/Seasonal Décor
# Home/Storage & Organization
# Kids/Bathing & Skin Care
# Kids/Boys (4+)
# Kids/Boys 0-24 Mos
# Kids/Boys 2T-5T
# Kids/Car Seats & Accessories
# Kids/Diapering
# Kids/Feeding
# Kids/Gear
# Kids/Girls (4+)
# Kids/Girls 0-24 Mos
# Kids/Girls 2T-5T
# Kids/Health & Baby Care
# Kids/Nursery
# Kids/Other
# Kids/Potty Training
# Kids/Pregnancy & Maternity
# Kids/Safety
# Kids/Strollers
# Kids/Toys
# Men/Athletic Apparel
# Men/Blazers & Sport Coats
# Men/Coats & Jackets
# Men/Jeans
# Men/Men's Accessories
# Men/Other
# Men/Pants
# Men/Shoes
# Men/Shorts
# Men/Suits
# Men/Sweaters
# Men/Sweats & Hoodies
# Men/Swimwear
# Men/Tops
# Other/Automotive
# Other/Books
# Other/Daily & Travel items
# Other/Magazines
# Other/Musical instruments
# Other/Office supplies
# Other/Other
# Other/Pet Supplies
# Sports & Outdoors/Apparel
# Sports & Outdoors/Exercise
# Sports & Outdoors/Fan Shop
# Sports & Outdoors/Footwear
# Sports & Outdoors/Golf
# Sports & Outdoors/Other
# Sports & Outdoors/Outdoors
# Sports & Outdoors/Team Sports
# Vintage & Collectibles/Accessories
# Vintage & Collectibles/Antique
# Vintage & Collectibles/Bags and Purses
# Vintage & Collectibles/Book
# Vintage & Collectibles/Clothing
# Vintage & Collectibles/Collectibles
# Vintage & Collectibles/Electronics
# Vintage & Collectibles/Furniture
# Vintage & Collectibles/Home Decor
# Vintage & Collectibles/Housewares
# Vintage & Collectibles/Jewelry
# Vintage & Collectibles/Other
# Vintage & Collectibles/Paper Ephemera
# Vintage & Collectibles/Serving
# Vintage & Collectibles/Supplies
# Vintage & Collectibles/Toy
# Vintage & Collectibles/Trading Cards
# Women/Athletic Apparel
# Women/Coats & Jackets
# Women/Dresses
# Women/Jeans
# Women/Jewelry
# Women/Maternity
# Women/Other
# Women/Pants
# Women/Shoes
# Women/Skirts
# Women/Suits & Blazers
# Women/Sweaters
# Women/Swimwear
# Women/Tops & Blouses
# Women/Underwear
# Women/Women's Accessories
# Women/Women's Handbags

# %%
# The first few rows of the training data
train_df.head()
# Out:
#                                          name item_condition_id  \
# train_id
# 0         MLB Cincinnati Reds T Shirt Size XL                 3
# 1            Razer BlackWidow Chroma Keyboard                 3
# 2                              AVA-VIV Blouse                 1
# 3                       Leather Horse Statues                 1
# 4                        24K GOLD plated rose                 1
#
#                                               category_name brand_name  price  \
# train_id
# 0                                         Men/Tops/T-shirts        NaN   10.0
# 1         Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                               Women/Tops & Blouses/Blouse     Target   10.0
# 3                        Home/Home Décor/Home Décor Accents        NaN   35.0
# 4                                   Women/Jewelry/Necklaces        NaN   44.0
#
#          shipping                                   item_description  \
# train_id
# 0               1                                 No description yet
# 1               0  This keyboard is in great condition and works ...
# 2               1  Adorable top with a hint of lace and a key hol...
# 3               1  New with tags. Leather horses. Retail for [rm]...
# 4               0          Complete with certificate of authenticity
#
#          category_oneLevel                category_twoLevel  \
# train_id
# 0                      Men                         Men/Tops
# 1              Electronics  Electronics/Computers & Tablets
# 2                    Women             Women/Tops & Blouses
# 3                     Home                  Home/Home Décor
# 4                    Women                    Women/Jewelry
#
#                                         category_threeLevel
# train_id
# 0                                         Men/Tops/T-shirts
# 1         Electronics/Computers & Tablets/Components & P...
# 2                               Women/Tops & Blouses/Blouse
# 3                        Home/Home Décor/Home Décor Accents
# 4                                   Women/Jewelry/Necklaces

# %%
# Create column for (adult) clothing type that does not distinguish gender
# NaN's stand for all the items that are not clothing, or have no category (but could be clothing anyway)
# Note: This probably could have been dong without try-except

def get_clothing_type(elem):
    try:
        cat = elem['category_name'].split("/")
        if cat[0] in ['Men', 'Women']: return cat[1]
        else: return np.nan  
    except AttributeError: return np.nan # This error means that the category_name was NaN in the first place

train_df['clothing_type'] = train_df.apply(get_clothing_type, axis = 1).astype('category')

# %%
# The first few rows of the training data with the new transformed columns

train_df.head(20)
# Out:
#                                             name item_condition_id  \
# train_id
# 0            MLB Cincinnati Reds T Shirt Size XL                 3
# 1               Razer BlackWidow Chroma Keyboard                 3
# 2                                 AVA-VIV Blouse                 1
# 3                          Leather Horse Statues                 1
# 4                           24K GOLD plated rose                 1
# 5               Bundled items requested for Ruie                 3
# 6             Acacia pacific tides santorini top                 3
# 7           Girls cheer and tumbling bundle of 7                 3
# 8                          Girls Nike Pro shorts                 3
# 9         Porcelain clown doll checker pants VTG                 3
# 10                               Smashbox primer                 2
# 11                        New vs pi k body mists                 1
# 12                            Black Skater dress                 2
# 13                          Sharpener and eraser                 1
# 14            HOLD for Dogs2016 Minnetonka boots                 3
# 15                   Sephora tarte birthday gift                 1
# 16                             Glitter Eyeshadow                 1
# 17           New: Baby K'tan active baby carrier                 1
# 18           Too Faced Limited "Merry Macaroons"                 1
# 19                Cream/ Beige Front Cross Shirt                 2
#
#                                               category_name  \
# train_id
# 0                                         Men/Tops/T-shirts
# 1         Electronics/Computers & Tablets/Components & P...
# 2                               Women/Tops & Blouses/Blouse
# 3                        Home/Home Décor/Home Décor Accents
# 4                                   Women/Jewelry/Necklaces
# 5                                         Women/Other/Other
# 6                                  Women/Swimwear/Two-Piece
# 7                           Sports & Outdoors/Apparel/Girls
# 8                           Sports & Outdoors/Apparel/Girls
# 9                  Vintage & Collectibles/Collectibles/Doll
# 10                                       Beauty/Makeup/Face
# 11                                   Beauty/Fragrance/Women
# 12                           Women/Dresses/Above Knee, Mini
# 13                    Other/Office supplies/School Supplies
# 14                                        Women/Shoes/Boots
# 15                                Beauty/Makeup/Makeup Sets
# 16                                       Beauty/Makeup/Eyes
# 17                           Kids/Gear/Backpacks & Carriers
# 18                            Beauty/Makeup/Makeup Palettes
# 19                              Women/Tops & Blouses/Blouse
#
#                  brand_name  price shipping  \
# train_id
# 0                       NaN   10.0        1
# 1                     Razer   52.0        0
# 2                    Target   10.0        1
# 3                       NaN   35.0        1
# 4                       NaN   44.0        0
# 5                       NaN   59.0        0
# 6           Acacia Swimwear   64.0        0
# 7                     Soffe    6.0        1
# 8                      Nike   19.0        0
# 9                       NaN    8.0        0
# 10                 Smashbox    8.0        1
# 11        Victoria's Secret   34.0        0
# 12                      rue   16.0        0
# 13               Scholastic    4.0        1
# 14            UGG Australia   43.0        0
# 15                    Tarte   11.0        1
# 16               Wet n Wild    6.0        1
# 17                      NaN   29.0        1
# 18                Too Faced   25.0        1
# 19            Anthropologie   27.0        0
#
#                                            item_description  \
# train_id
# 0                                        No description yet
# 1         This keyboard is in great condition and works ...
# 2         Adorable top with a hint of lace and a key hol...
# 3         New with tags. Leather horses. Retail for [rm]...
# 4                 Complete with certificate of authenticity
# 5         Banana republic bottoms, Candies skirt with ma...
# 6         Size small but straps slightly shortened to fi...
# 7         You get three pairs of Sophie cheer shorts siz...
# 8          Girls Size small Plus green. Three shorts total.
# 9         I realized his pants are on backwards after th...
# 10             0.25 oz Full size is 1oz for [rm] in Sephora
# 11        (5) new vs pink body mists (2.5 oz each) Fresh...
# 12                                      Xl, great condition
# 13                                       No description yet
# 14        Authentic. Suede fringe boots. Great condition...
# 15        Brand new. Deluxe travel size products. Contai...
# 16        2 glitter eyeshadows; one in Brass and one in ...
# 17        Brand new in box Size: Medium Color: Coral Ret...
# 18        This AUTHENTIC pallete by Too Faced is brand n...
# 19        Fancy, dressy or casual! Dress it up or down 1...
#
#                category_oneLevel                    category_twoLevel  \
# train_id
# 0                            Men                             Men/Tops
# 1                    Electronics      Electronics/Computers & Tablets
# 2                          Women                 Women/Tops & Blouses
# 3                           Home                      Home/Home Décor
# 4                          Women                        Women/Jewelry
# 5                          Women                          Women/Other
# 6                          Women                       Women/Swimwear
# 7              Sports & Outdoors            Sports & Outdoors/Apparel
# 8              Sports & Outdoors            Sports & Outdoors/Apparel
# 9         Vintage & Collectibles  Vintage & Collectibles/Collectibles
# 10                        Beauty                        Beauty/Makeup
# 11                        Beauty                     Beauty/Fragrance
# 12                         Women                        Women/Dresses
# 13                         Other                Other/Office supplies
# 14                         Women                          Women/Shoes
# 15                        Beauty                        Beauty/Makeup
# 16                        Beauty                        Beauty/Makeup
# 17                          Kids                            Kids/Gear
# 18                        Beauty                        Beauty/Makeup
# 19                         Women                 Women/Tops & Blouses
#
#                                         category_threeLevel   clothing_type
# train_id
# 0                                         Men/Tops/T-shirts            Tops
# 1         Electronics/Computers & Tablets/Components & P...             NaN
# 2                               Women/Tops & Blouses/Blouse  Tops & Blouses
# 3                        Home/Home Décor/Home Décor Accents             NaN
# 4                                   Women/Jewelry/Necklaces         Jewelry
# 5                                         Women/Other/Other           Other
# 6                                  Women/Swimwear/Two-Piece        Swimwear
# 7                           Sports & Outdoors/Apparel/Girls             NaN
# 8                           Sports & Outdoors/Apparel/Girls             NaN
# 9                  Vintage & Collectibles/Collectibles/Doll             NaN
# 10                                       Beauty/Makeup/Face             NaN
# 11                                   Beauty/Fragrance/Women             NaN
# 12                           Women/Dresses/Above Knee, Mini         Dresses
# 13                    Other/Office supplies/School Supplies             NaN
# 14                                        Women/Shoes/Boots           Shoes
# 15                                Beauty/Makeup/Makeup Sets             NaN
# 16                                       Beauty/Makeup/Eyes             NaN
# 17                           Kids/Gear/Backpacks & Carriers             NaN
# 18                            Beauty/Makeup/Makeup Palettes             NaN
# 19                              Women/Tops & Blouses/Blouse  Tops & Blouses

# %%
# Basic statistics about price, the only numerical category in the data

train_df.describe()
# Out:
#               price
# count  1.482535e+06
# mean   2.673752e+01
# std    3.858607e+01
# min    0.000000e+00
# 25%    1.000000e+01
# 50%    1.700000e+01
# 75%    2.900000e+01
# max    2.009000e+03

# %%
# A logarithmically scaled histogram of the price distribution

plt.hist(train_df.price[train_df.price > 0], bins=10**np.linspace(0, 3, 25))
plt.title('Log scaled price distribution histogram')
plt.xscale('log') 
plt.show()

# %%
# This probability plot tests whether log-transformed prices are normally distributed.
# They seem to be heavy-tailed on the right, which is a pattern that mirrors pricing in financial markets (leptokurtosis)
# The heavy right tail is also visible in the histogram above
stats.probplot(np.log(train_df.price[train_df.price > 0]), dist = 'norm', plot = plt)
# Out:
# ((array([-4.90471412, -4.72767087, -4.63203236, ...,  4.63203236,
#           4.72767087,  4.90471412]),
#   array([1.09861229, 1.09861229, 1.09861229, ..., 7.60290046, 7.60389797,
#          7.60539236])),
#  (0.78126453350128, 2.9129305217149466, 0.9902626442410368))

# %%
# The number of items with each item condition category
train_df.item_condition_id.value_counts()
# Out:
# 1    640549
# 3    432161
# 2    375479
# 4     31962
# 5      2384
# Name: item_condition_id, dtype: int64

# %%
# A bar plot of the number of items with each item condition category, graphical representation of the above cell
# I think pandas has a simplier method for a categorical series object, I'm not sure I needed to set this up myself in matplotlib

y_pos = np.arange(len(train_df.item_condition_id.value_counts()))
plt.bar(y_pos, train_df.item_condition_id.value_counts(), align='center', alpha=0.5)
plt.xticks(y_pos, train_df.item_condition_id.cat.categories.values)
plt.ylabel('Number of items')
plt.xlabel('Item condition number')

# %%
# The next goal is to figure out, within each category, and then as a whole, the proportion of the error that can be eliminated by specifying the category.
# Based on intuition from visual inspection of the names of the categories, it seems that specifying the second level category plausibly eliminates much of the error.

# You could change the lambda functions to ordinary functions to make this more readable
mean_log =  lambda x: np.mean(np.log(x + 1))
std_log = lambda x: np.std(np.log(x + 1))
sem_log = lambda x: np.std(np.log(x + 1))/x.count()
cat_statistics = {'mean' : np.mean, 'mean log': mean_log, 'std log' : std_log, 'sem log' : sem_log}

# Log price stats for whole dataset
# price_statistics assignment currently leading to error involving trying to concatate floats
price_stats = train_df.price.apply(cat_statistics)
# Category stats

category2_price_stats = train_df.groupby('category_twoLevel').price.agg(cat_statistics)

print(price_stats)
print(category2_price_stats)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-5cca3517e10c> in <module>()
#       6 sem_log = lambda x: np.std(np.log(x + 1))/x.count()
#       7 cat_statistics = {'mean' : np.mean, 'mean log': mean_log, 'std log' : std_log, 'sem log' : sem_log}
# ----> 8 price_stats = train_df.price.apply(cat_statistics)
#       9 # Category stats
#      10 category2_price_stats = train_df.groupby('category_twoLevel').price.agg(cat_statistics)
#
# /Users/Abe/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2528         # dispatch to agg
#    2529         if isinstance(func, (list, dict)):
# -> 2530             return self.aggregate(func, *args, **kwds)
#    2531
#    2532         # if we are a string, try to dispatch
#
# /Users/Abe/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in aggregate(self, func, axis, *args, **kwargs)
#    2399     def aggregate(self, func, axis=0, *args, **kwargs):
#    2400         axis = self._get_axis_number(axis)
# -> 2401         result, how = self._aggregate(func, *args, **kwargs)
#    2402         if result is None:
#    2403
#
# /Users/Abe/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     476
#     477                 try:
# --> 478                     result = _agg(arg, _agg_1dim)
#     479                 except SpecificationError:
#     480
#
# /Users/Abe/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in _agg(arg, func)
#     427                 result = compat.OrderedDict()
#     428                 for fname, agg_how in compat.iteritems(arg):
# --> 429                     result[fname] = func(fname, agg_how)
#     430                 return result
#     431
#
# /Users/Abe/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in _agg_1dim(name, how, subset)
#     410                     raise SpecificationError("nested dictionary is ambiguous "
#     411                                              "in aggregation")
# --> 412                 return colg.aggregate(how, _level=(_level or 0) + 1)
#     413
#     414             def _agg_2dim(name, how):
#
# /Users/Abe/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in aggregate(self, func, axis, *args, **kwargs)
#    2416             # operation is actually defined on the Series, e.g. str
#    2417             try:
# -> 2418                 result = self.apply(func, *args, **kwargs)
#    2419             except (ValueError, AttributeError, TypeError):
#    2420                 result = func(self, *args, **kwargs)
#
# /Users/Abe/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-55-5cca3517e10c> in <lambda>(x)
#       3 # Log price stats
#       4 mean_log =  lambda x: np.mean(np.log(x + 1))
# ----> 5 std_log = lambda x: np.std(np.log(x + 1))
#       6 sem_log = lambda x: np.std(np.log(x + 1))/x.count()
#       7 cat_statistics = {'mean' : np.mean, 'mean log': mean_log, 'std log' : std_log, 'sem log' : sem_log}
#
# /Users/Abe/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in std(a, axis, dtype, out, ddof, keepdims)
#    3070             pass
#    3071         else:
# -> 3072             return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
#    3073
#    3074     return _methods._std(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
#
# /Users/Abe/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _std(a, axis, dtype, out, ddof, keepdims)
#     133 def _std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=False):
#     134     ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# --> 135                keepdims=keepdims)
#     136
#     137     if isinstance(ret, mu.ndarray):
#
# /Users/Abe/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py in _var(a, axis, dtype, out, ddof, keepdims)
#     110     # Note that x may not be inexact and that we need it to be an array,
#     111     # not a scalar.
# --> 112     x = asanyarray(arr - arrmean)
#     113     if issubclass(arr.dtype.type, nt.complexfloating):
#     114         x = um.multiply(x, um.conjugate(x), out=x).real
#
# KeyboardInterrupt:

# %%
# Planning to regress price on the category names
# This needs to be changed to log price as is done with the rest of this notebook
result = sm.ols(formula = 'price ~ category_twoLevel', data = train_df).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.083
# Model:                            OLS   Adj. R-squared:                  0.083
# Method:                 Least Squares   F-statistic:                     977.4
# Date:                Wed, 17 Jan 2018   Prob (F-statistic):               0.00
# Time:                        06:15:28   Log-Likelihood:            -7.4237e+06
# No. Observations:             1476208   AIC:                         1.485e+07
# Df Residuals:                 1476070   BIC:                         1.485e+07
# Df Model:                         137
# Covariance Type:            nonrobust
# ===============================================================================================================================
#                                                                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                      19.0847      0.420     45.474      0.000      18.262      19.907
# category_twoLevel[T.Beauty/Fragrance]                           4.7164      0.482      9.784      0.000       3.772       5.661
# category_twoLevel[T.Beauty/Hair Care]                           0.2900      0.593      0.489      0.625      -0.873       1.453
# category_twoLevel[T.Beauty/Makeup]                             -0.3985      0.433     -0.921      0.357      -1.246       0.449
# category_twoLevel[T.Beauty/Other]                               3.8683      1.724      2.244      0.025       0.490       7.246
# category_twoLevel[T.Beauty/Skin Care]                           1.4130      0.471      2.999      0.003       0.490       2.336
# category_twoLevel[T.Beauty/Tools & Accessories]                 0.8228      0.530      1.553      0.120      -0.216       1.861
# category_twoLevel[T.Electronics/Cameras & Photography]         52.2591      0.721     72.484      0.000      50.846      53.672
# category_twoLevel[T.Electronics/Car Audio, Video & GPS]        18.7893      1.681     11.180      0.000      15.496      22.083
# category_twoLevel[T.Electronics/Cell Phones & Accessories]     11.0576      0.449     24.617      0.000      10.177      11.938
# category_twoLevel[T.Electronics/Computers & Tablets]           68.8031      0.600    114.700      0.000      67.627      69.979
# category_twoLevel[T.Electronics/Media]                         -4.4854      0.542     -8.274      0.000      -5.548      -3.423
# category_twoLevel[T.Electronics/Other]                         18.2103      1.394     13.061      0.000      15.478      20.943
# category_twoLevel[T.Electronics/TV, Audio & Surveillance]      25.0749      0.571     43.922      0.000      23.956      26.194
# category_twoLevel[T.Electronics/Video Games & Consoles]        12.9168      0.463     27.914      0.000      12.010      13.824
# category_twoLevel[T.Handmade/Accessories]                       0.2013      0.637      0.316      0.752      -1.047       1.450
# category_twoLevel[T.Handmade/Art]                              -4.3362      1.503     -2.885      0.004      -7.282      -1.390
# category_twoLevel[T.Handmade/Bags and Purses]                  17.0785      0.779     21.930      0.000      15.552      18.605
# category_twoLevel[T.Handmade/Books and Zines]                  -4.8456      5.466     -0.886      0.375     -15.560       5.868
# category_twoLevel[T.Handmade/Candles]                           2.6497      4.640      0.571      0.568      -6.444      11.743
# category_twoLevel[T.Handmade/Ceramics and Pottery]              1.1960      4.914      0.243      0.808      -8.436      10.828
# category_twoLevel[T.Handmade/Children]                         -6.4204      1.130     -5.683      0.000      -8.635      -4.206
# category_twoLevel[T.Handmade/Clothing]                         -0.2012      0.647     -0.311      0.756      -1.469       1.067
# category_twoLevel[T.Handmade/Crochet]                          -0.0163      2.453     -0.007      0.995      -4.823       4.791
# category_twoLevel[T.Handmade/Dolls and Miniatures]              8.3847      5.297      1.583      0.113      -1.998      18.767
# category_twoLevel[T.Handmade/Furniture]                        -7.4180     21.346     -0.348      0.728     -49.256      34.420
# category_twoLevel[T.Handmade/Geekery]                          -7.0938      3.549     -1.999      0.046     -14.051      -0.137
# category_twoLevel[T.Handmade/Glass]                            -0.3127      1.576     -0.198      0.843      -3.402       2.777
# category_twoLevel[T.Handmade/Holidays]                         -3.1831      2.093     -1.521      0.128      -7.285       0.919
# category_twoLevel[T.Handmade/Housewares]                       -1.8109      1.829     -0.990      0.322      -5.396       1.775
# category_twoLevel[T.Handmade/Jewelry]                          -6.5345      0.864     -7.567      0.000      -8.227      -4.842
# category_twoLevel[T.Handmade/Knitting]                          2.6822      2.926      0.917      0.359      -3.052       8.416
# category_twoLevel[T.Handmade/Music]                             2.8011      1.324      2.116      0.034       0.207       5.396
# category_twoLevel[T.Handmade/Needlecraft]                      -3.7858      2.284     -1.657      0.097      -8.263       0.692
# category_twoLevel[T.Handmade/Other]                            -4.6691      1.959     -2.383      0.017      -8.510      -0.829
# category_twoLevel[T.Handmade/Others]                           -4.0782      2.144     -1.902      0.057      -8.281       0.125
# category_twoLevel[T.Handmade/Paper Goods]                      -8.3104      0.629    -13.202      0.000      -9.544      -7.077
# category_twoLevel[T.Handmade/Patterns]                          3.4005      2.635      1.291      0.197      -1.763       8.564
# category_twoLevel[T.Handmade/Pets]                             -1.2992      2.326     -0.559      0.576      -5.859       3.260
# category_twoLevel[T.Handmade/Quilts]                           -6.8266      6.652     -1.026      0.305     -19.865       6.212
# category_twoLevel[T.Handmade/Toys]                             -5.3653      1.794     -2.990      0.003      -8.882      -1.849
# category_twoLevel[T.Handmade/Weddings]                          1.0757      1.553      0.693      0.489      -1.969       4.120
# category_twoLevel[T.Handmade/Woodworking]                       2.7335      3.387      0.807      0.420      -3.904       9.371
# category_twoLevel[T.Home/Artwork]                              -5.0882      1.121     -4.538      0.000      -7.286      -2.891
